# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#import Excel file and plot the data in a graph using pandas
data = pd.read_excel('space_decay.xlsx')

# %%
# filter all data that is not numeric comment
# filter all data that is not numeric
#data_N = data[data.apply(lambda x: x.dtype != 'object')]
# create correlation matrix
corr = data.corr()

# %%
# plot the correlation matrix
#cols = data.columns.tolist()
#cols = sorted(cols, key=lambda x: corr[x].values[0], reverse=True)
# plot the sorted data
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(data[cols].corr(), vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
#filter
