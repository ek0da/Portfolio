# %%
install.packages('readr')
install.packages("tidyverse")
install.packages("skimr")
install.packages("janitor")
install.packages('kimisc')
install.packages('dplyr')
install.packages('stringr')
install.packages('lubridate')
install.packages('hms')

# %%
# Out:
# Installing package into 'C:/Users/dakot/AppData/Local/R/win-library/4.2'
# (as 'lib' is unspecified)
# package 'hms' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\dakot\AppData\Local\Temp\RtmpQvWY80\downloaded_packages

# %%
library(readr)
library(kimisc)
library(dplyr)
library(stringr)
library(tidyverse)
library(skimr)
library(janitor)
library(lubridate)
library(hms)
# Out:
# Attaching package: 'hms'
#
#
# The following object is masked from 'package:lubridate':
#
#     hms

# %%
cdata1 <- read_csv("Cleaned Data//202101-divvy-tripdata.csv")
cdata2 <- read_csv("Cleaned Data//202102-divvy-tripdata.csv")
cdata3 <- read_csv("Cleaned Data//202103-divvy-tripdata.csv")
cdata4 <- read_csv("Cleaned Data//202104-divvy-tripdata.csv")
cdata5 <- read_csv("Cleaned Data//202105-divvy-tripdata.csv")
cdata6a <- read_csv("Cleaned Data//202106A-divvy-tripdata.csv")
cdata6b <- read_csv("Cleaned Data//202106B-divvy-tripdata.csv")
cdata7a <- read_csv("Cleaned Data//202107A-divvy-tripdata.csv")
cdata7b <- read_csv("Cleaned Data//202107B-divvy-tripdata.csv")
cdata8a <- read_csv("Cleaned Data//202108A-divvy-tripdata.csv")
cdata8b <- read_csv("Cleaned Data//202108B-divvy-tripdata.csv")
cdata9a <- read_csv("Cleaned Data//202109A-divvy-tripdata.csv")
cdata9b <- read_csv("Cleaned Data//202109B-divvy-tripdata.csv")
cdata10a <- read_csv("Cleaned Data//202110A-divvy-tripdata.csv")
cdata10b <- read_csv("Cleaned Data//202110B-divvy-tripdata.csv")
cdata11 <- read_csv("Cleaned Data//202111-divvy-tripdata.csv")
cdata12 <- read_csv("Cleaned Data//202112-divvy-tripdata.csv")
# Out:
# Warning message:
# "One or more parsing issues, see `problems()` for details"
# Rows: 96834 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (9): ride_id, rideable_type, started_at, ended_at, start_station_name, ...
# dbl  (5): day_of_week, start_lat, start_lng, end_lat, end_lng
# time (1): ride_length
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `end_station_name` -> `end_station_name...9`
# • `end_station_name` -> `end_station_name...10`
# Warning message:
# "One or more parsing issues, see `problems()` for details"
# Rows: 49622 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# ...

# %%
cdata6a$ride_length <- parse_hms(cdata6a$ride_length)

# %%
head(cdata6a)
# Out:
#   ride_id          rideable_type started_at          ended_at
# 1 99FEC93BA843FB20 electric_bike 2021-06-13 14:31:28 2021-06-13 14:34:11
# 2 06048DCFC8520CAF electric_bike 2021-06-04 11:18:02 2021-06-04 11:24:19
# 3 9598066F68045DF2 electric_bike 2021-06-04 9:49:35  2021-06-04 9:55:34
# 4 B03C0FE48C412214 electric_bike 2021-06-03 19:56:05 2021-06-03 20:21:55
# 5 B9EEA89F8FEE73B7 electric_bike 2021-06-04 14:05:51 2021-06-04 14:09:59
# 6 62B943CEAAA420BA electric_bike 2021-06-03 19:32:01 2021-06-03 19:38:46
#   ride_length day_of_week start_station_name start_station_id end_station_name
# 1 00:02:43    1           NA                 NA               NA
# 2 00:06:17    6           NA                 NA               NA
# 3 00:05:59    6           NA                 NA               NA
# 4 00:25:50    5           NA                 NA               NA
# 5 00:04:08    6           NA                 NA               NA
# 6 00:06:45    5           NA                 NA               NA
# ...

# %%
hms(1234,0,0)
# Out:
# 00:20:34

# %%
clean_data <- rbind(read_csv("Cleaned Data//202101-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202102-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202103-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202104-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202105-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202106A-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202106B-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202107A-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202107B-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202108A-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202108B-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202109A-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202109B-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202110A-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202110B-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202111-divvy-tripdata.csv"),
                    read_csv("Cleaned Data//202112-divvy-tripdata.csv"))
# Out:
# Warning message:
# "One or more parsing issues, see `problems()` for details"
# Rows: 96834 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (9): ride_id, rideable_type, started_at, ended_at, start_station_name, ...
# dbl  (5): day_of_week, start_lat, start_lng, end_lat, end_lng
# time (1): ride_length
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `end_station_name` -> `end_station_name...9`
# • `end_station_name` -> `end_station_name...10`
# Warning message:
# "One or more parsing issues, see `problems()` for details"
# Rows: 49622 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# ...
